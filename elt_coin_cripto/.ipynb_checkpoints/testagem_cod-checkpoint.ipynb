# %%
#############################################################################
############### Executor da Extração, Transformação e Carga  ################
#############################################################################

from ast import Str, Try
import json
from sqlite3 import Date
from sqlalchemy import create_engine, Column, Integer, String, DateTime, Float, null
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from coin_model import Coins
from requests import Request, Session
from datetime import datetime
import pandas as pd 
import coin_config

def check_if_valid_data(df: pd.DataFrame) -> bool:

    # checar se o DF está 'vazio'
    if df.empty:
        print('\nDataFrame empty. Finishing execution')
        return False
    
    # checar se há 'códigos da moeda' como 'null'
    if df.symbol.empty:
        raise Exception('\nSymbol is Null or the valuer is empty')
    
    # checar se há 'preços' como 'null'
    if df.price.empty:
        raise Exception('\nPrice is Null or the value is empty')
    
    # checar se há 'datas' como 'null'
    if df.data_added.empty:
        raise Exception('\nData is Null or the value is empty')
    
    return True

# %%
def load_data(table_name, coins_df, session_db, engine_db):

    # validando
    if check_if_valid_data(coins_df):
        print('\nData valid, proceed to Load stage')

    # carregando os 'dados' no DB
    try:
        coins_df.to_sql(table_name, engine_db, index=False, if_exists='append')
        print('\nData Loaded on Database')

    except:
        print('\nFail to load data on Database')

    session_db.commit()
    session_db.close()
    print('\nClose Database successfully')
    return session_db

# %%
def get_data(session_db, engine_db, start, limit, convert, key, url):
    
    # definindo limite de dados da 'API'
    parameters = {
        'start': start,
        'limit': limit,
        'convert': convert,
    } 

    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': key,
    }

    session = Session()
    session.headers.update(headers)

    name = []
    symbol = []
    date_added = []
    last_updated = []
    price = []
    volume_24h = []

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        print(data)
        
        print("\n")
        for coin in data['data']:
            name.append(coin['name'])

            symbol.append(coin['symbol'])
            
            date_added.append(coin['date_added'])
            
            last_updated.append(coin['last_updated'])
            
            price.append(coin['quote']['USD']['price'])
            
            volume_24h.append(coin['quote']['USD']['volume_24h'])
        
        # gerando um dicionário para transforma-lo em um DF 
        coin_dict = {
            'name': name,
            'symbol': symbol,
            'data_added': date_added,
            'last_update': last_updated,
            'price': price,
            'volume_24h': volume_24h,
        }
    except (ConnectionError, Timeout, TooManyRedirects) as error:
        print(error)
    """
    # criando um DF com dados 'estruturados'
    coins_df = pd.DataFrame(coin_dict, columns=['name','symbol','data_added','last_updated','price','volume_24h'])
    print("Data on Pandas DataFrame:\n")
    print(coins_df.head())

    # chamando a função para carregar os 'dados' no DB
    load_data('Coins',coins_df, session_db,engine_db)
    """

# %%
# base de declaração
Base = declarative_base()

# fazer uma 'table' das 'moedas'
get_session_db, get_engine = Coins.start()

# chamando a função 'get_data' e carregando os dados no Db
get_data(get_session_db,
         get_engine,
         '1',
         '50',
         coin_config.api_currency,
         coin_config.api_key,
         coin_config.api_url)
# Out:
# postgresql://postgres:#Mb368936@e-d-db-coin.cisvuqjrzfih.us-east-2.rds.amazonaws.com:5432/coins
#
# Table created on Database
# {'status': {'timestamp': '2023-07-18T02:50:58.631Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 10114}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10346, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19432250, 'total_supply': 19432250, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T02:48:00.000Z', 'quote': {'USD': {'price': 30124.13228873381, 'volume_24h': 13291352741.567802, 'volume_change_24h': 59.8364, 'percent_change_1h': -0.25415727, 'percent_change_24h': -0.58579014, 'percent_change_7d': -1.24219183, 'percent_change_30d': 13.82300037, 'percent_change_60d': 12.50511558, 'percent_change_90d': -0.2789695, 'market_cap': 585379669667.7476, 'market_cap_dominance': 48.5109, 'fully_diluted_market_cap': 632606778063.41, 'tvl': None, 'last_updated': '2023-07-18T02:48:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7128, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120200809.62935519, 'total_supply': 120200809.62935519, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T02:48:00.000Z', 'quote': {'USD': {'price': 1909.1407705579556, 'volume_24h': 6589548943.787145, 'volume_change_24h': 51.5603, 'percent_change_1h': -0.26009688, 'percent_change_24h': -1.00864854, 'percent_change_7d': 1.56710585, 'percent_change_30d': 10.65542627, 'percent_change_60d': 6.16943373, 'percent_change_90d': -8.77113916, 'market_cap': 229480266317.4773, 'market_cap_dominance': 19.0157, 'fully_diluted_market_cap': 229480266317.48, 'tvl': None, 'last_updated': '2023-07-18T02:48:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 57051, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83750478228.26431, 'total_supply': 86715788906.04521, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET ...
#
#
# Data on Pandas DataFrame:
#
#        name symbol                data_added last_updated         price  \
# 0   Bitcoin    BTC  2010-07-13T00:00:00.000Z          NaN  30124.132289
# 1  Ethereum    ETH  2015-08-07T00:00:00.000Z          NaN   1909.140771
# 2    Tether   USDT  2015-02-25T00:00:00.000Z          NaN      1.000189
# 3       XRP    XRP  2013-08-04T00:00:00.000Z          NaN      0.738194
# 4       BNB    BNB  2017-07-25T00:00:00.000Z          NaN    245.874327
#
#      volume_24h
# 0  1.329135e+10
# 1  6.589549e+09
# 2  2.448775e+10
# 3  2.417348e+09
# 4  6.434288e+08
#
# Data valid, proceed to Load stage
# Data Loaded on Database
#
# Close Database successfully

# %%
print(last_updated)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(last_updated)
#
# NameError: name 'last_updated' is not defined
